# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.utils import shuffle
from tensorflow.keras import utils
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB1  
from sklearn.model_selection import KFold
import os

# Define label-to-class and class-to-label mappings
label_to_class = {
    'Mild_Demented': 0,
    'Moderate_Demented': 1,
    'Non_Demented': 2,
    'Very_Mild_Demented': 3,
}

class_to_label = {v: k for k, v in label_to_class.items()}
n_classes = len(label_to_class)

def get_images(dir_name="C:/Dataset", label_to_class=label_to_class):
    # Read images/labels from directory
    Images = []
    Classes = []
    for j in ["data"]:
        for label_name in os.listdir(os.path.join(dir_name, j)):
            cls1 = label_to_class[label_name]
            for img_name in os.listdir(os.path.join(dir_name, j, label_name)):
                # Load the image
                img = load_img(os.path.join(dir_name, j, label_name, img_name), target_size=(128, 128))  # Adjust size for EfficientNetB7
                # Convert the image to a NumPy array
                img = img_to_array(img)
                Images.append(img)
                Classes.append(cls1)

    Images = np.array(Images, dtype=np.float16)
    Classes = np.array(Classes, dtype=np.float16)
    Images, Classes = shuffle(Images, Classes, random_state=0)

    return Images, Classes

Images, Classes = get_images()
y_train_all = utils.to_categorical(Classes, num_classes=n_classes)

def EfficientNetModel(cf):
    inputs = tf.keras.layers.Input(shape=(128, 128, 3))

    
    # Pre-trained EfficientNetB7
    efficientnet = EfficientNetB1(include_top=False, weights="imagenet", input_tensor=inputs)
    output = efficientnet.output

    # Convolutional Layer
    x = Conv2D(256, kernel_size=(3, 3), padding="same", activation="relu")(output)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)

    # Fully Connected Layers
    x = Dense(128, activation="relu")(x)
    x = Dropout(0.2)(x)

    logits = Dense(cf["num_classes"])(x)

    model = Model(inputs=inputs, outputs=logits)

    return model

def run_kfold_experiment(model, k=5):
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    kf = KFold(n_splits=k, shuffle=True, random_state=0)
    fold = 1
    test_accuracies = []
    all_conf_matrices = []  # To store confusion matrices for each split
    all_class_reports = []  # To store classification reports for each split
    all_histories = []
    all_fprs = []  # To store false positive rates for each fold
    all_tprs = []  # To store true positive rates for each fold
   

    for fold, (train_idx, test_idx) in enumerate(kf.split(Images, y_train_all), 1):
        print(f"Training fold {fold}/{k}")
        x_train, x_test = Images[train_idx], Images[test_idx]
        y_train, y_test = y_train_all[train_idx], y_train_all[test_idx]
 
        history = model.fit(
            x_train,
            y_train,
            batch_size=64,
            epochs=20,
        )
        all_histories.append(history.history)

        # Evaluate the model on the test set to get test accuracy
        _, test_accuracy = model.evaluate(x_test, y_test)
        test_accuracies.append(test_accuracy)

        # Calculate and store the confusion matrix for this fold
        y_pred_fold = model.predict(x_test).argmax(axis=1)
        conf_matrix_fold = confusion_matrix(y_test.argmax(axis=1), y_pred_fold)
        all_conf_matrices.append(conf_matrix_fold)

        # Calculate and store the classification report for this fold
        class_report_fold = classification_report(y_test.argmax(axis=1), y_pred_fold, target_names=class_to_label.values(), output_dict=True)
        all_class_reports.append(class_report_fold)
        fold += 1

    print(f"Average Test accuracy: {round(np.mean(test_accuracies) * 100, 2)}%")
    return all_histories, all_conf_matrices, all_class_reports, all_fprs, all_tprs

config = {
    "num_classes": n_classes
}

# Create EfficientNetB7 model
with tf.distribute.MirroredStrategy().scope():
    efficientnet_classifier = EfficientNetModel(config)
    histories, conf_matrices, class_reports, all_fprs, all_tprs = run_kfold_experiment(efficientnet_classifier, k=5)
# Out:
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Training fold 1/5
# Epoch 1/20
# 25/25 [==============================] - 363s 11s/step - loss: 1.0390 - accuracy: 0.5381
# Epoch 2/20
# 25/25 [==============================] - 221s 9s/step - loss: 0.6018 - accuracy: 0.7400
# Epoch 3/20
# 25/25 [==============================] - 152s 6s/step - loss: 0.3999 - accuracy: 0.8500
# Epoch 4/20
# 25/25 [==============================] - 147s 6s/step - loss: 0.2768 - accuracy: 0.9094
# Epoch 5/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.1575 - accuracy: 0.9419
# Epoch 6/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.1091 - accuracy: 0.9631
# Epoch 7/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0899 - accuracy: 0.9737
# Epoch 8/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0763 - accuracy: 0.9719
# Epoch 9/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0695 - accuracy: 0.9769
# Epoch 10/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0522 - accuracy: 0.9844
# Epoch 11/20
# 25/25 [==============================] - 141s 6s/step - loss: 0.0530 - accuracy: 0.9850
# Epoch 12/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0469 - accuracy: 0.9850
# Epoch 13/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0362 - accuracy: 0.9869
# Epoch 14/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0500 - accuracy: 0.9862
# Epoch 15/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0328 - accuracy: 0.9881
# Epoch 16/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0226 - accuracy: 0.9931
# Epoch 17/20
# 25/25 [==============================] - 165s 7s/step - loss: 0.0257 - accuracy: 0.9937
# Epoch 18/20
# 25/25 [==============================] - 218s 9s/step - loss: 0.0498 - accuracy: 0.9850
# Epoch 19/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0303 - accuracy: 0.9875
# Epoch 20/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0348 - accuracy: 0.9869
# 13/13 [==============================] - 13s 563ms/step - loss: 0.8501 - accuracy: 0.6875
# 13/13 [==============================] - 10s 564ms/step
# Training fold 2/5
# Epoch 1/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0679 - accuracy: 0.9800
# Epoch 2/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0599 - accuracy: 0.9800
# Epoch 3/20
# 25/25 [==============================] - 141s 6s/step - loss: 0.0368 - accuracy: 0.9912
# Epoch 4/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0329 - accuracy: 0.9894
# Epoch 5/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0274 - accuracy: 0.9881
# Epoch 6/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0185 - accuracy: 0.9925
# Epoch 7/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0167 - accuracy: 0.9937
# Epoch 8/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0182 - accuracy: 0.9969
# Epoch 9/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0106 - accuracy: 0.9962
# Epoch 10/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0229 - accuracy: 0.9944
# Epoch 11/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0218 - accuracy: 0.9925
# Epoch 12/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0274 - accuracy: 0.9925
# Epoch 13/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0134 - accuracy: 0.9962
# Epoch 14/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0059 - accuracy: 0.9994
# Epoch 15/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0082 - accuracy: 0.9956
# Epoch 16/20
# 25/25 [==============================] - 155s 6s/step - loss: 0.0105 - accuracy: 0.9975
# Epoch 17/20
# 25/25 [==============================] - 149s 6s/step - loss: 0.0201 - accuracy: 0.9925
# Epoch 18/20
# 25/25 [==============================] - 150s 6s/step - loss: 0.0210 - accuracy: 0.9944
# Epoch 19/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0154 - accuracy: 0.9944
# Epoch 20/20
# 25/25 [==============================] - 155s 6s/step - loss: 0.0156 - accuracy: 0.9956
# 13/13 [==============================] - 7s 562ms/step - loss: 5.6945e-04 - accuracy: 1.0000
# 13/13 [==============================] - 8s 562ms/step
# Training fold 3/5
# Epoch 1/20
# 25/25 [==============================] - 147s 6s/step - loss: 0.0140 - accuracy: 0.9950
# Epoch 2/20
# 25/25 [==============================] - 262s 11s/step - loss: 0.0122 - accuracy: 0.9969
# Epoch 3/20
# 25/25 [==============================] - 284s 11s/step - loss: 0.0106 - accuracy: 0.9975
# Epoch 4/20
# 25/25 [==============================] - 273s 11s/step - loss: 0.0144 - accuracy: 0.9969
# Epoch 5/20
# 25/25 [==============================] - 272s 11s/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 6/20
# 25/25 [==============================] - 281s 11s/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 7/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0062 - accuracy: 0.9975
# Epoch 8/20
# 25/25 [==============================] - 281s 11s/step - loss: 0.0154 - accuracy: 0.9950
# Epoch 9/20
# 25/25 [==============================] - 166s 6s/step - loss: 0.0218 - accuracy: 0.9931
# Epoch 10/20
# 25/25 [==============================] - 173s 7s/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 11/20
# 25/25 [==============================] - 5183s 215s/step - loss: 0.0130 - accuracy: 0.9962
# Epoch 12/20
# 25/25 [==============================] - 283s 11s/step - loss: 0.0069 - accuracy: 0.9981
# Epoch 13/20
# 25/25 [==============================] - 285s 11s/step - loss: 0.0134 - accuracy: 0.9944
# Epoch 14/20
# 25/25 [==============================] - 281s 11s/step - loss: 0.0185 - accuracy: 0.9944
# Epoch 15/20
# 25/25 [==============================] - 280s 11s/step - loss: 0.0094 - accuracy: 0.9975
# Epoch 16/20
# 25/25 [==============================] - 285s 11s/step - loss: 0.0096 - accuracy: 0.9962
# Epoch 17/20
# 25/25 [==============================] - 281s 11s/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 18/20
# 25/25 [==============================] - 283s 11s/step - loss: 0.0154 - accuracy: 0.9956
# Epoch 19/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0109 - accuracy: 0.9962
# Epoch 20/20
# 25/25 [==============================] - 276s 11s/step - loss: 0.0028 - accuracy: 1.0000
# 13/13 [==============================] - 19s 1s/step - loss: 2.3979e-04 - accuracy: 1.0000
# 13/13 [==============================] - 17s 1s/step
# Training fold 4/5
# Epoch 1/20
# 25/25 [==============================] - 284s 11s/step - loss: 0.0188 - accuracy: 0.9950
# Epoch 2/20
# 25/25 [==============================] - 283s 11s/step - loss: 0.0058 - accuracy: 0.9987
# Epoch 3/20
# 25/25 [==============================] - 283s 11s/step - loss: 0.0099 - accuracy: 0.9975
# Epoch 4/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0137 - accuracy: 0.9956
# Epoch 5/20
# 25/25 [==============================] - 280s 11s/step - loss: 0.0092 - accuracy: 0.9969
# Epoch 6/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0099 - accuracy: 0.9962
# Epoch 7/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0208 - accuracy: 0.9950
# Epoch 8/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 9/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0130 - accuracy: 0.9969
# Epoch 10/20
# 25/25 [==============================] - 282s 11s/step - loss: 0.0088 - accuracy: 0.9956
# Epoch 11/20
# 25/25 [==============================] - 235s 9s/step - loss: 0.0064 - accuracy: 0.9969
# Epoch 12/20
# 25/25 [==============================] - 149s 6s/step - loss: 0.0110 - accuracy: 0.9975
# Epoch 13/20
# 25/25 [==============================] - 147s 6s/step - loss: 0.0089 - accuracy: 0.9975
# Epoch 14/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 15/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 16/20
# 25/25 [==============================] - 144s 6s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0102 - accuracy: 0.9981
# Epoch 18/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0103 - accuracy: 0.9956
# Epoch 19/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0128 - accuracy: 0.9975
# 13/13 [==============================] - 8s 562ms/step - loss: 0.0022 - accuracy: 0.9975
# 13/13 [==============================] - 8s 613ms/step
# Training fold 5/5
# Epoch 1/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0036 - accuracy: 0.9987
# Epoch 2/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0081 - accuracy: 0.9981
# Epoch 3/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0101 - accuracy: 0.9987
# Epoch 4/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0096 - accuracy: 0.9956
# Epoch 5/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0051 - accuracy: 0.9981
# Epoch 6/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0182 - accuracy: 0.9975
# Epoch 7/20
# 25/25 [==============================] - 141s 6s/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 8/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0079 - accuracy: 0.9969
# Epoch 9/20
# 25/25 [==============================] - 146s 6s/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 10/20
# 25/25 [==============================] - 154s 6s/step - loss: 0.0034 - accuracy: 0.9994
# Epoch 11/20
# 25/25 [==============================] - 157s 6s/step - loss: 0.0024 - accuracy: 0.9981
# Epoch 12/20
# 25/25 [==============================] - 145s 6s/step - loss: 0.0144 - accuracy: 0.9975
# Epoch 13/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0027 - accuracy: 0.9987
# Epoch 14/20
# 25/25 [==============================] - 141s 6s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 16/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0038 - accuracy: 0.9994
# Epoch 17/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0045 - accuracy: 0.9994
# Epoch 18/20
# 25/25 [==============================] - 142s 6s/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 19/20
# 25/25 [==============================] - 143s 6s/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 20/20
# 25/25 [==============================] - 141s 6s/step - loss: 0.0102 - accuracy: 0.9987
# 13/13 [==============================] - 8s 558ms/step - loss: 4.2475e-05 - accuracy: 1.0000
# 13/13 [==============================] - 8s 577ms/step
# Average Test accuracy: 93.7%

# %%
# Function to plot accuracy and loss
def plot_accuracy_loss(histories):
    plt.figure(figsize=(10, 5))
    
    for i, history in enumerate(histories):
        plt.subplot(1, 2, 1)
        plt.plot(history['accuracy'], label=f'Fold {i+1}')
        plt.title('Model Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        
        plt.subplot(1, 2, 2)
        plt.plot(history['loss'], label=f'Fold {i+1}')
        plt.title('Model Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
    
    plt.tight_layout()
    plt.legend()
    plt.show()
    # Plot accuracy and loss
plot_accuracy_loss(histories)

# Print classification reports for each fold
for i, class_report in enumerate(class_reports):
    print(f"Classification Report - Fold {i+1}:\n")
    print(class_report)
    print("-" * 60)
# Out:
# Classification Report - Fold 1:
#
# {'Mild_Demented': {'precision': 0.9183673469387755, 'recall': 0.40540540540540543, 'f1-score': 0.5625, 'support': 111}, 'Moderate_Demented': {'precision': 0.697841726618705, 'recall': 1.0, 'f1-score': 0.8220338983050847, 'support': 97}, 'Non_Demented': {'precision': 0.5657894736842105, 'recall': 0.945054945054945, 'f1-score': 0.7078189300411523, 'support': 91}, 'Very_Mild_Demented': {'precision': 0.7833333333333333, 'recall': 0.46534653465346537, 'f1-score': 0.5838509316770186, 'support': 101}, 'accuracy': 0.6875, 'macro avg': {'precision': 0.7413329701437561, 'recall': 0.703951721278454, 'f1-score': 0.6690509400058139, 'support': 400}, 'weighted avg': {'precision': 0.7505823294103706, 'recall': 0.6875, 'f1-score': 0.6638881371717923, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 2:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 86}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 103}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 102}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 109}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 3:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 102}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 97}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 119}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 82}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 4:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 96}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 95}, 'Non_Demented': {'precision': 0.9906542056074766, 'recall': 1.0, 'f1-score': 0.9953051643192489, 'support': 106}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 0.9902912621359223, 'f1-score': 0.9951219512195122, 'support': 103}, 'accuracy': 0.9975, 'macro avg': {'precision': 0.9976635514018691, 'recall': 0.9975728155339806, 'f1-score': 0.9976067788846903, 'support': 400}, 'weighted avg': {'precision': 0.9975233644859813, 'recall': 0.9975, 'f1-score': 0.9974997709836253, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 5:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 105}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 108}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 82}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 105}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------

# %%
# Plot confusion matrix for each fold
def plot_confusion_matrix(conf_matrix, class_names):
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# Plot confusion matrices for each fold
for i, conf_matrix in enumerate(conf_matrices):
    class_names = [class_to_label[idx] for idx in range(n_classes)]
    plot_confusion_matrix(conf_matrix, class_names)
