# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.utils import shuffle
from tensorflow.keras import utils
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50 
from sklearn.model_selection import KFold
import os

# Define label-to-class and class-to-label mappings
label_to_class = {
    'Mild_Demented': 0,
    'Moderate_Demented': 1,
    'Non_Demented': 2,
    'Very_Mild_Demented': 3,
}

class_to_label = {v: k for k, v in label_to_class.items()}
n_classes = len(label_to_class)

def get_images(dir_name="C:/Dataset", label_to_class=label_to_class):
    # Read images/labels from directory
    Images = []
    Classes = []
    for j in ["data"]:
        for label_name in os.listdir(os.path.join(dir_name, j)):
            cls1 = label_to_class[label_name]
            for img_name in os.listdir(os.path.join(dir_name, j, label_name)):
                # Load the image
                img = load_img(os.path.join(dir_name, j, label_name, img_name), target_size=(128, 128))  # Adjust size for EfficientNetB7
                # Convert the image to a NumPy array
                img = img_to_array(img)
                Images.append(img)
                Classes.append(cls1)

    Images = np.array(Images, dtype=np.float16)
    Classes = np.array(Classes, dtype=np.float16)
    Images, Classes = shuffle(Images, Classes, random_state=0)

    return Images, Classes

Images, Classes = get_images()
y_train_all = utils.to_categorical(Classes, num_classes=n_classes)


def ResNet50Model(cf):
    inputs = tf.keras.layers.Input(shape=(128, 128, 3))

    
   # Pre-trained ResNet-50
    resnet = ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    output = resnet.output

    # Convolutional Layer
    x = Conv2D(256, kernel_size=(3, 3), padding="same", activation="relu")(output)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)

    # Fully Connected Layers
    x = Dense(128, activation="relu")(x)
    x = Dropout(0.2)(x)

    logits = Dense(cf["num_classes"])(x)

    model = Model(inputs=inputs, outputs=logits)

    return model

def run_kfold_experiment(model, k=5):
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    kf = KFold(n_splits=k, shuffle=True, random_state=0)
    fold = 1
    test_accuracies = []
    all_conf_matrices = []  # To store confusion matrices for each split
    all_class_reports = []  # To store classification reports for each split
    all_histories = []
    all_fprs = []  # To store false positive rates for each fold
    all_tprs = []  # To store true positive rates for each fold
   

    for fold, (train_idx, test_idx) in enumerate(kf.split(Images, y_train_all), 1):
        print(f"Training fold {fold}/{k}")
        x_train, x_test = Images[train_idx], Images[test_idx]
        y_train, y_test = y_train_all[train_idx], y_train_all[test_idx]
 
        history = model.fit(
            x_train,
            y_train,
            batch_size=64,
            epochs=20,
        )
        all_histories.append(history.history)

        # Evaluate the model on the test set to get test accuracy
        _, test_accuracy = model.evaluate(x_test, y_test)
        test_accuracies.append(test_accuracy)

        # Calculate and store the confusion matrix for this fold
        y_pred_fold = model.predict(x_test).argmax(axis=1)
        conf_matrix_fold = confusion_matrix(y_test.argmax(axis=1), y_pred_fold)
        all_conf_matrices.append(conf_matrix_fold)

        # Calculate and store the classification report for this fold
        class_report_fold = classification_report(y_test.argmax(axis=1), y_pred_fold, target_names=class_to_label.values(), output_dict=True)
        all_class_reports.append(class_report_fold)
        fold += 1

    print(f"Average Test accuracy: {round(np.mean(test_accuracies) * 100, 2)}%")
    return all_histories, all_conf_matrices, all_class_reports, all_fprs, all_tprs

config = {
    "num_classes": n_classes
}

# Create ResNet-50 model
with tf.distribute.MirroredStrategy().scope():
    resnet_classifier = ResNet50Model(config)
    histories, conf_matrices, class_reports, all_fprs, all_tprs = run_kfold_experiment(resnet_classifier, k=5)
# Out:
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Training fold 1/5
# Epoch 1/20
# 25/25 [==============================] - 272s 10s/step - loss: 0.7784 - accuracy: 0.6494
# Epoch 2/20
# 25/25 [==============================] - 236s 9s/step - loss: 0.2189 - accuracy: 0.9306
# Epoch 3/20
# 25/25 [==============================] - 225s 9s/step - loss: 0.0621 - accuracy: 0.9862
# Epoch 4/20
# 25/25 [==============================] - 228s 9s/step - loss: 0.0609 - accuracy: 0.9750
# Epoch 5/20
# 25/25 [==============================] - 233s 9s/step - loss: 0.0446 - accuracy: 0.9850
# Epoch 6/20
# 25/25 [==============================] - 234s 9s/step - loss: 0.0533 - accuracy: 0.9819
# Epoch 7/20
# 25/25 [==============================] - 228s 9s/step - loss: 0.0817 - accuracy: 0.9744
# Epoch 8/20
# 25/25 [==============================] - 229s 9s/step - loss: 0.0725 - accuracy: 0.9825
# Epoch 9/20
# 25/25 [==============================] - 233s 9s/step - loss: 0.0342 - accuracy: 0.9881
# Epoch 10/20
# 25/25 [==============================] - 231s 9s/step - loss: 0.0201 - accuracy: 0.9962
# Epoch 11/20
# 25/25 [==============================] - 234s 9s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 12/20
# 25/25 [==============================] - 235s 9s/step - loss: 0.0012 - accuracy: 0.9994
# Epoch 13/20
# 25/25 [==============================] - 227s 9s/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 14/20
# 25/25 [==============================] - 241s 10s/step - loss: 0.0045 - accuracy: 0.9994
# Epoch 15/20
# 25/25 [==============================] - 254s 10s/step - loss: 7.8396e-04 - accuracy: 1.0000
# Epoch 16/20
# 25/25 [==============================] - 270s 11s/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 267s 11s/step - loss: 0.0204 - accuracy: 0.9944
# Epoch 18/20
# 25/25 [==============================] - 251s 10s/step - loss: 0.0335 - accuracy: 0.9912
# Epoch 19/20
# 25/25 [==============================] - 250s 10s/step - loss: 0.0286 - accuracy: 0.9906
# Epoch 20/20
# 25/25 [==============================] - 243s 10s/step - loss: 0.0442 - accuracy: 0.9844
# 13/13 [==============================] - 15s 833ms/step - loss: 0.5090 - accuracy: 0.8825
# 13/13 [==============================] - 13s 893ms/step
# Training fold 2/5
# Epoch 1/20
# 25/25 [==============================] - 275s 11s/step - loss: 0.0674 - accuracy: 0.9806
# Epoch 2/20
# 25/25 [==============================] - 274s 11s/step - loss: 0.0585 - accuracy: 0.9856
# Epoch 3/20
# 25/25 [==============================] - 239s 10s/step - loss: 0.0158 - accuracy: 0.9962
# Epoch 4/20
# 25/25 [==============================] - 227s 9s/step - loss: 0.0292 - accuracy: 0.9931
# Epoch 5/20
# 25/25 [==============================] - 227s 9s/step - loss: 0.0218 - accuracy: 0.9919
# Epoch 6/20
# 25/25 [==============================] - 228s 9s/step - loss: 0.0085 - accuracy: 0.9975
# Epoch 7/20
# 25/25 [==============================] - 228s 9s/step - loss: 0.0103 - accuracy: 0.9950
# Epoch 8/20
# 25/25 [==============================] - 231s 9s/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 9/20
# 25/25 [==============================] - 227s 9s/step - loss: 8.8892e-04 - accuracy: 1.0000
# Epoch 10/20
# 25/25 [==============================] - 228s 9s/step - loss: 4.0621e-04 - accuracy: 1.0000
# Epoch 11/20
# 25/25 [==============================] - 229s 9s/step - loss: 0.0011 - accuracy: 0.9994
# Epoch 12/20
# 25/25 [==============================] - 229s 9s/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 13/20
# 25/25 [==============================] - 9670s 403s/step - loss: 0.0318 - accuracy: 0.9919
# Epoch 14/20
# 25/25 [==============================] - 449s 18s/step - loss: 0.0393 - accuracy: 0.9894
# Epoch 15/20
# 25/25 [==============================] - 450s 18s/step - loss: 0.0045 - accuracy: 0.9994
# Epoch 16/20
# 25/25 [==============================] - 450s 18s/step - loss: 5.0500e-04 - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 450s 18s/step - loss: 4.0598e-04 - accuracy: 1.0000
# Epoch 18/20
# 25/25 [==============================] - 449s 18s/step - loss: 1.8978e-04 - accuracy: 1.0000
# Epoch 19/20
# 25/25 [==============================] - 449s 18s/step - loss: 1.1003e-04 - accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 449s 18s/step - loss: 1.8877e-04 - accuracy: 1.0000
# 13/13 [==============================] - 23s 2s/step - loss: 0.0018 - accuracy: 1.0000
# 13/13 [==============================] - 23s 2s/step
# Training fold 3/5
# Epoch 1/20
# 25/25 [==============================] - 451s 18s/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 2/20
# 25/25 [==============================] - 450s 18s/step - loss: 9.4036e-04 - accuracy: 1.0000
# Epoch 3/20
# 25/25 [==============================] - 449s 18s/step - loss: 3.8852e-04 - accuracy: 1.0000
# Epoch 4/20
# 25/25 [==============================] - 391s 16s/step - loss: 3.7505e-04 - accuracy: 1.0000
# Epoch 5/20
# 25/25 [==============================] - 231s 9s/step - loss: 5.7937e-05 - accuracy: 1.0000
# Epoch 6/20
# 25/25 [==============================] - 226s 9s/step - loss: 5.0647e-05 - accuracy: 1.0000
# Epoch 7/20
# 25/25 [==============================] - 226s 9s/step - loss: 4.5789e-04 - accuracy: 1.0000
# Epoch 8/20
# 25/25 [==============================] - 227s 9s/step - loss: 3.0629e-04 - accuracy: 1.0000
# Epoch 9/20
# 25/25 [==============================] - 224s 9s/step - loss: 6.4238e-04 - accuracy: 1.0000
# Epoch 10/20
# 25/25 [==============================] - 226s 9s/step - loss: 6.0422e-05 - accuracy: 1.0000
# Epoch 11/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.0463e-04 - accuracy: 1.0000
# Epoch 12/20
# 25/25 [==============================] - 227s 9s/step - loss: 2.0655e-05 - accuracy: 1.0000
# Epoch 13/20
# 25/25 [==============================] - 225s 9s/step - loss: 4.9802e-05 - accuracy: 1.0000
# Epoch 14/20
# 25/25 [==============================] - 225s 9s/step - loss: 2.7906e-05 - accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.2462e-05 - accuracy: 1.0000
# Epoch 16/20
# 25/25 [==============================] - 224s 9s/step - loss: 3.8566e-05 - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 227s 9s/step - loss: 7.1864e-06 - accuracy: 1.0000
# Epoch 18/20
# 25/25 [==============================] - 224s 9s/step - loss: 2.2282e-04 - accuracy: 1.0000
# Epoch 19/20
# 25/25 [==============================] - 225s 9s/step - loss: 1.3299e-04 - accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 224s 9s/step - loss: 2.6463e-05 - accuracy: 1.0000
# 13/13 [==============================] - 10s 779ms/step - loss: 7.9808e-07 - accuracy: 1.0000
# 13/13 [==============================] - 11s 809ms/step
# Training fold 4/5
# Epoch 1/20
# 25/25 [==============================] - 225s 9s/step - loss: 5.6962e-05 - accuracy: 1.0000
# Epoch 2/20
# 25/25 [==============================] - 226s 9s/step - loss: 6.9662e-05 - accuracy: 1.0000
# Epoch 3/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.3076e-05 - accuracy: 1.0000
# Epoch 4/20
# 25/25 [==============================] - 223s 9s/step - loss: 1.4808e-05 - accuracy: 1.0000
# Epoch 5/20
# 25/25 [==============================] - 224s 9s/step - loss: 6.4695e-05 - accuracy: 1.0000
# Epoch 6/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.6424e-05 - accuracy: 1.0000
# Epoch 7/20
# 25/25 [==============================] - 225s 9s/step - loss: 1.0267e-05 - accuracy: 1.0000
# Epoch 8/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.5255e-05 - accuracy: 1.0000
# Epoch 9/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.3712e-05 - accuracy: 1.0000
# Epoch 10/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.1794e-05 - accuracy: 1.0000
# Epoch 11/20
# 25/25 [==============================] - 232s 9s/step - loss: 1.0938e-05 - accuracy: 1.0000
# Epoch 12/20
# 25/25 [==============================] - 231s 9s/step - loss: 6.3934e-06 - accuracy: 1.0000
# Epoch 13/20
# 25/25 [==============================] - 234s 9s/step - loss: 2.1159e-05 - accuracy: 1.0000
# Epoch 14/20
# 25/25 [==============================] - 300s 12s/step - loss: 2.8475e-05 - accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 448s 18s/step - loss: 1.1497e-05 - accuracy: 1.0000
# Epoch 16/20
# 25/25 [==============================] - 449s 18s/step - loss: 7.2673e-06 - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 449s 18s/step - loss: 4.5910e-06 - accuracy: 1.0000
# Epoch 18/20
# 25/25 [==============================] - 450s 18s/step - loss: 5.1409e-06 - accuracy: 1.0000
# Epoch 19/20
# 25/25 [==============================] - 449s 18s/step - loss: 1.2941e-05 - accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 448s 18s/step - loss: 1.5429e-05 - accuracy: 1.0000
# 13/13 [==============================] - 23s 2s/step - loss: 4.7386e-08 - accuracy: 1.0000
# 13/13 [==============================] - 23s 2s/step
# Training fold 5/5
# Epoch 1/20
# 25/25 [==============================] - 450s 18s/step - loss: 5.3085e-05 - accuracy: 1.0000
# Epoch 2/20
# 25/25 [==============================] - 421s 17s/step - loss: 1.4717e-05 - accuracy: 1.0000
# Epoch 3/20
# 25/25 [==============================] - 232s 9s/step - loss: 9.9469e-06 - accuracy: 1.0000
# Epoch 4/20
# 25/25 [==============================] - 225s 9s/step - loss: 5.9165e-06 - accuracy: 1.0000
# Epoch 5/20
# 25/25 [==============================] - 224s 9s/step - loss: 2.6900e-05 - accuracy: 1.0000
# Epoch 6/20
# 25/25 [==============================] - 224s 9s/step - loss: 9.6481e-06 - accuracy: 1.0000
# Epoch 7/20
# 25/25 [==============================] - 223s 9s/step - loss: 5.4103e-06 - accuracy: 1.0000
# Epoch 8/20
# 25/25 [==============================] - 223s 9s/step - loss: 1.7796e-05 - accuracy: 1.0000
# Epoch 9/20
# 25/25 [==============================] - 224s 9s/step - loss: 8.2859e-06 - accuracy: 1.0000
# Epoch 10/20
# 25/25 [==============================] - 222s 9s/step - loss: 1.2061e-05 - accuracy: 1.0000
# Epoch 11/20
# 25/25 [==============================] - 226s 9s/step - loss: 1.8408e-05 - accuracy: 1.0000
# Epoch 12/20
# 25/25 [==============================] - 224s 9s/step - loss: 4.3096e-06 - accuracy: 1.0000
# Epoch 13/20
# 25/25 [==============================] - 224s 9s/step - loss: 4.3196e-06 - accuracy: 1.0000
# Epoch 14/20
# 25/25 [==============================] - 224s 9s/step - loss: 3.0803e-06 - accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 224s 9s/step - loss: 1.3584e-05 - accuracy: 1.0000
# Epoch 16/20
# 25/25 [==============================] - 223s 9s/step - loss: 1.0126e-05 - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 225s 9s/step - loss: 3.0273e-06 - accuracy: 1.0000
# Epoch 18/20
# 25/25 [==============================] - 224s 9s/step - loss: 2.7922e-06 - accuracy: 1.0000
# Epoch 19/20
# 25/25 [==============================] - 225s 9s/step - loss: 2.1080e-06 - accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 223s 9s/step - loss: 1.1325e-05 - accuracy: 1.0000
# 13/13 [==============================] - 11s 832ms/step - loss: 1.0431e-08 - accuracy: 1.0000
# 13/13 [==============================] - 21s 761ms/step
# Average Test accuracy: 97.65%

# %%
# Function to plot accuracy and loss
def plot_accuracy_loss(histories):
    plt.figure(figsize=(10, 5))
    
    for i, history in enumerate(histories):
        plt.subplot(1, 2, 1)
        plt.plot(history['accuracy'], label=f'Fold {i+1}')
        plt.title('Model Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        
        plt.subplot(1, 2, 2)
        plt.plot(history['loss'], label=f'Fold {i+1}')
        plt.title('Model Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
    
    plt.tight_layout()
    plt.legend()
    plt.show()
    # Plot accuracy and loss
plot_accuracy_loss(histories)

# Print classification reports for each fold
for i, class_report in enumerate(class_reports):
    print(f"Classification Report - Fold {i+1}:\n")
    print(class_report)
    print("-" * 60)
# Out:
# Classification Report - Fold 1:
#
# {'Mild_Demented': {'precision': 0.9298245614035088, 'recall': 0.954954954954955, 'f1-score': 0.9422222222222222, 'support': 111}, 'Moderate_Demented': {'precision': 0.8899082568807339, 'recall': 1.0, 'f1-score': 0.941747572815534, 'support': 97}, 'Non_Demented': {'precision': 0.7711864406779662, 'recall': 1.0, 'f1-score': 0.8708133971291866, 'support': 91}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 0.5841584158415841, 'f1-score': 0.7374999999999999, 'support': 101}, 'accuracy': 0.8825, 'macro avg': {'precision': 0.8977298147405522, 'recall': 0.8847783426991348, 'f1-score': 0.8730707980417356, 'support': 400}, 'weighted avg': {'precision': 0.9017739833372889, 'recall': 0.8825, 'f1-score': 0.8741692509213236, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 2:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 86}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 103}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 102}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 109}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 3:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 102}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 97}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 119}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 82}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 4:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 96}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 95}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 106}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 103}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------
# Classification Report - Fold 5:
#
# {'Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 105}, 'Moderate_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 108}, 'Non_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 82}, 'Very_Mild_Demented': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 105}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 400}}
# ------------------------------------------------------------

# %%
# Plot confusion matrix for each fold
def plot_confusion_matrix(conf_matrix, class_names):
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# Plot confusion matrices for each fold
for i, conf_matrix in enumerate(conf_matrices):
    class_names = [class_to_label[idx] for idx in range(n_classes)]
    plot_confusion_matrix(conf_matrix, class_names)
